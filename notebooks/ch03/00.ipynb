# %%
import pandas as pd

orders = pd.read_csv("../../data/raw/orders.csv")

# %%
print(orders.head())
# Out:
#    order_id  customer_id  order_date status
# 0         1            6  2026-02-08    배송중
# 1         2          151  2026-02-20    배송중
# 2         3            2  2025-10-02   결제완료
# 3         4          182  2026-04-23   결제완료
# 4         5           59  2026-04-23   결제완료

# %%
df =  orders[["customer_id", "order_date"]]
print(type(df))
print(df)
# Out:
# <class 'pandas.DataFrame'>
#      customer_id  order_date
# 0              6  2026-02-08
# 1            151  2026-02-20
# 2              2  2025-10-02
# 3            182  2026-04-23
# 4             59  2026-04-23
# ..           ...         ...
# 495          164  2026-04-19
# 496           28  2026-02-16
# 497          121  2026-07-03
# 498          159  2026-02-18
# 499          157  2026-04-10
#
# [500 rows x 2 columns]

# %%
print(orders.columns)
# Out:
# Index(['order_id', 'customer_id', 'order_date', 'status'], dtype='str')
